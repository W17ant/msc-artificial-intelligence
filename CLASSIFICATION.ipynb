# %%
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt 
import tensorflow as tf

# %%
#Loading the dataset BC
dataset_BC = pd.read_csv ("breast_cancer.csv") 
dataset_BC.head ()
# Out:
#          id  diagnosis_Num  radius_mean  texture_mean  perimeter_mean  \
# 0    842302              1        17.99         10.38          122.80
# 1    842517              1        20.57         17.77          132.90
# 2  84300903              1        19.69         21.25          130.00
# 3  84348301              1        11.42         20.38           77.58
# 4  84358402              1        20.29         14.34          135.10
#
#    area_mean  smoothness_mean  compactness_mean  concavity_mean  \
# 0     1001.0          0.11840           0.27760          0.3001
# 1     1326.0          0.08474           0.07864          0.0869
# 2     1203.0          0.10960           0.15990          0.1974
# 3      386.1          0.14250           0.28390          0.2414
# 4     1297.0          0.10030           0.13280          0.1980
#
#    concave points_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0              0.14710  ...         25.38          17.33           184.60
# ...

# %%
dataset_BC.shape
# Out:
# (569, 32)

# %%
dataset_BC['diagnosis_Num'].value_counts ()
# Out:
# diagnosis_Num
# 0    357
# 1    212
# Name: count, dtype: int64

# %%
dataset_BC.groupby ('diagnosis_Num' ).size ()
# Out:
# diagnosis_Num
# 0    357
# 1    212
# dtype: int64

# %%
# Splitting the dataset 
X = dataset_BC.loc [:, dataset_BC.columns!= " diagnosis_Num "  ] 
Y = dataset_BC.loc [:, "diagnosis_Num" ]

# %%
from sklearn.preprocessing import MinMaxScaler 

mmScaler = MinMaxScaler() 
X = mmScaler.fit_transform( X.astype (float) )

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test , Y_train , Y_test = train_test_split ( X, Y, test_size = 0.2 , random_state = 0  )

# %%
# Creating a Neural Network 

from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense , Activation 
from tensorflow.keras.optimizers import Adam

# %%
# Building the networks 

model = Sequential() 
model.add(Dense (30 , activation = "relu" ) ) 
model.add ( Dense ( 30 , activation = "relu" ) ) 
model.add ( Dense ( 30, activation = "relu" ) ) 
model.add ( Dense ( 2, activation = tf.nn.softmax ) )

# %%
model.compile ( optimizer = "Adam" , loss = "Sparse_categorical_crossentropy", metrics = [ " accuracy " ]  )

# %%
model.fit(X_train, Y_train.values, epochs = 100, validation_data (X_test, Y_test) )
# Out:
#   Cell In[67], line 1
#     model.fit(X_train, Y_train.values, epochs = 100, validation_data (X_test , Y_test) )
#                                                                                        ^
# SyntaxError: positional argument follows keyword argument

# %%
predictions = model.predict ( X_test ) 
print ( predictions ) 
print ( Y_test )
